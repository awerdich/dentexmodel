# %% [markdown]
# ## Train Faster R-CNN model on dentex image data ##
#
# Model description for the "faster_rcnn_R_101_FPN_3x" model:
#
# https://github.com/facebookresearch/detectron2/blob/main/MODEL_ZOO.md
#
# Weights configuration file:
#
# https://github.com/facebookresearch/detectron2/blob/main/configs/COCO-Detection/faster_rcnn_R_101_FPN_3x.yaml
#
# This notebooks requires the detectron2 library.

# %%
# Imports
import os
import numpy as np
import pandas as pd
import json
import glob
from matplotlib import pyplot as plt
from pathlib import Path

# Appearance of the Notebook
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
np.set_printoptions(linewidth=110)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)

# PyTorch libraries
import torch

# Detectron2 library
import detectron2
from detectron2 import model_zoo
from detectron2.config import get_cfg
from detectron2.structures import BoxMode
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# Import this module with autoreload
# %load_ext autoreload
# %autoreload 2
import dentexmodel as dm
from dentexmodel.imageproc import ImageData
from dentexmodel.detector import Trainer

print(f'Project module version: {dm.__version__}')
print(f'Detectron2 version:     {detectron2.__version__}')
# Out:
# <style>.container { width:100% !important; }</style>
# Project module version: 0.0.post1.dev138+gcadc7f7.d20240218
# Detectron2 version:     0.6

# %%
# GPU checks
is_cuda = torch.cuda.is_available()
print(f'CUDA available: {is_cuda}')
print(f'Number of GPUs found:  {torch.cuda.device_count()}')

if is_cuda:
    print(f'Current device ID:     {torch.cuda.current_device()}')
    print(f'GPU device name:       {torch.cuda.get_device_name(0)}')
    print(f'CUDNN version:         {torch.backends.cudnn.version()}')
    device_str = 'cuda:0'
    torch.cuda.empty_cache() 
else:
    device_str = 'cpu'
device = torch.device(device_str)
print()
print(f'Device for model training/inference: {device}')
# Out:
# CUDA available: True
# Number of GPUs found:  1
# Current device ID:     0
# GPU device name:       NVIDIA GeForce RTX 3070 Laptop GPU
# CUDNN version:         8902
#
# Device for model training/inference: cuda:0

# %%
# Data directory (change as needed)
dentex_dir = os.path.join(os.environ['HOME'], 'data', 'dentex')
data_dir = os.path.join(dentex_dir, 'dentex_detection')

# This image directory is where the xrays are in the archive, so should be left as-is
image_dir = os.path.join(data_dir, 'quadrant_enumeration', 'xrays')

# Annotation files (and make sure the files are where they should be.
annotation_files = {}
dataset_list = ['train', 'val', 'test']
annotation_name_list = [f'dentex_detection_{dataset}.json' for dataset in dataset_list]
annotation_file_list = [os.path.join(data_dir, file_name) for file_name in annotation_name_list]
annotation_file_dict = dict(zip(dataset_list, annotation_file_list))
for dataset, annotation_file in annotation_file_dict.items():
    if not os.path.exists(annotation_file):
        raise FileNotFoundError(f'Annotation "{json_file}" not found.')
    else:
        annotation_files.update({dataset: annotation_file})
display(annotation_files)
# Out:
# {'train': '/app/data/dentex/dentex_detection/dentex_detection_train.json',
#  'val': '/app/data/dentex/dentex_detection/dentex_detection_val.json',
#  'test': '/app/data/dentex/dentex_detection/dentex_detection_test.json'}

# %% [markdown]
# ### Register the dentex datasets ####

# %%
image_idx = 23
annotation_dict = {}
for dataset, annotation_file in annotation_file_dict.items():
    try:
        with open(annotation_file, 'r') as fl:
            annotations = json.load(fl)
    except FileNotFoundError:
        print(f'Annotation file not found: {annotation_file}')
        print('Make sure to run the annotations notebook.')
    else:
        annotation_dict.update({dataset: annotations})
        print(f'Loaded annotations for {len(annotations)} images for dataset "{dataset}".')

# Register the data sets
for dataset in dataset_list:
    dataset_name = f'dentex_{dataset}'
    if dataset_name not in DatasetCatalog:
        DatasetCatalog.register(name=dataset_name, func=lambda d=dataset: annotation_dict.get(d))
        MetadataCatalog.get(dataset_name).set(thing_classes=['tooth'])
# Out:
# Loaded annotations for 534 images for dataset "train".
# Loaded annotations for 50 images for dataset "val".
# Loaded annotations for 50 images for dataset "test".

# %%
# Plot one image from the training set
def show_image(image, figsize=(3, 3), title=''):
    fig, ax = plt.subplots(figsize=figsize)
    ax.imshow(image)
    ax.set_title(title)
    ax.set(xticks=[], yticks=[])
    return fig, ax

# Load one random image from the training set
dataset = 'dentex_train'
image_list = DatasetCatalog.get(dataset)
image_dict = np.random.choice(image_list, size=1)[0]
metadata = MetadataCatalog.get(dataset)
im = ImageData().load_image(image_dict.get('file_name'))
vs = Visualizer(img_rgb=im, metadata=metadata, scale = 1.0)
vs = vs.draw_dataset_dict(image_dict).get_image()
fig, ax = show_image(vs, figsize=(12, 3), title=f'Example image from dataset "{dataset}"')
plt.show()

# %% [markdown]
# ### Configure Faster R-CNN model for training ###

# %%
# Model definition
# For a description, see https://github.com/facebookresearch/detectron2/blob/main/MODEL_ZOO.md
# https://github.com/facebookresearch/detectron2/blob/main/configs/COCO-Detection/faster_rcnn_R_101_FPN_3x.yaml
model_config = os.path.join('COCO-Detection', 'faster_rcnn_R_101_FPN_3x.yaml')

# Create a directory for model checkpoints
model_dir = os.path.join(data_dir, 'model') 
Path(model_dir).mkdir(exist_ok=True, parents=True)

# Build configuration file
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file(model_config))

# Set the names for the datasets (as registered)
cfg.DATASETS.TRAIN = ('dentex_train', )
cfg.DATASETS.TEST = ('dentex_val', )
cfg.TEST.EVAL_PERIOD = 100
# The numbers of workers you can use depends on the number of cores and memory available per core
# Four workes is good for 32G memory
cfg.DATALOADER.NUM_WORKERS = 4
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url(model_config)
# The batch size needs to be adjusted according to the GPU memory
# A batch size of 4 works for and 8 GB GPU
cfg.SOLVER.IMS_PER_BATCH = 4
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.STEPS = []
cfg.SOLVER.MAX_ITER = 5000
cfg.SOLVER.CHECKPOINT_PERIOD = 500
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1
cfg.OUTPUT_DIR = model_dir
# Train on GPU or CPU
cfg.MODEL.DEVICE = device_str

# %%
# Train the model
trainer = Trainer(cfg)
trainer.resume_or_load(resume=True)
# Out:
# [02/18 23:28:01 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#     )
#   )
# )
# [02/18 23:28:01 d2.data.build]: Removed 0 images with no usable annotations. 534 images left.
# [02/18 23:28:01 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |   tooth    | 15242        |
# |            |              |
# [02/18 23:28:01 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [02/18 23:28:01 d2.data.build]: Using training sampler TrainingSampler
# [02/18 23:28:01 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/18 23:28:01 d2.data.common]: Serializing 534 elements to byte tensors and concatenating them all ...
# [02/18 23:28:01 d2.data.common]: Serialized dataset takes 1.09 MiB
# [02/18 23:28:01 d2.data.build]: Making batched data loader with batch_size=4
# [02/18 23:28:01 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [02/18 23:28:01 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |   tooth    | 1408         |
# |            |              |
# [02/18 23:28:01 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/18 23:28:01 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/18 23:28:01 d2.data.common]: Serialized dataset takes 0.10 MiB
# [02/18 23:28:01 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/faster_rcnn_R_101_FPN_3x/137851257/model_final_f6e8b1.pkl ...
# model_final_f6e8b1.pkl: 243MB [00:02, 105MB/s]
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (2, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (2,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (4, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (4,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}

# %%
trainer.train()
# Out:
# [02/18 23:28:04 d2.engine.train_loop]: Starting training from iteration 0
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [02/18 23:28:17 d2.utils.events]:  eta: 0:50:52  iter: 19  total_loss: 4.712  loss_cls: 0.6668  loss_box_reg: 0.6267  loss_rpn_cls: 3.191  loss_rpn_loc: 0.2912    time: 0.6157  last_time: 0.5978  data_time: 0.0179  last_data_time: 0.0057   lr: 4.9953e-06  max_mem: 5366M
# 2024-02-18 23:28:18.042976: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-18 23:28:18.043002: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-18 23:28:18.043999: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-18 23:28:18.049298: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-18 23:28:18.689411: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [02/18 23:28:31 d2.utils.events]:  eta: 0:49:44  iter: 39  total_loss: 2.013  loss_cls: 0.6313  loss_box_reg: 0.8333  loss_rpn_cls: 0.2879  loss_rpn_loc: 0.241    time: 0.6095  last_time: 0.6024  data_time: 0.0053  last_data_time: 0.0052   lr: 9.9902e-06  max_mem: 5367M
# [02/18 23:28:43 d2.utils.events]:  eta: 0:49:35  iter: 59  total_loss: 1.765  loss_cls: 0.6011  loss_box_reg: 0.8557  loss_rpn_cls: 0.08188  loss_rpn_loc: 0.2265    time: 0.6082  last_time: 0.6256  data_time: 0.0052  last_data_time: 0.0050   lr: 1.4985e-05  max_mem: 5367M
# [02/18 23:28:55 d2.utils.events]:  eta: 0:49:23  iter: 79  total_loss: 1.718  loss_cls: 0.5708  loss_box_reg: 0.8637  loss_rpn_cls: 0.06849  loss_rpn_loc: 0.2099    time: 0.6064  last_time: 0.5833  data_time: 0.0053  last_data_time: 0.0050   lr: 1.998e-05  max_mem: 5367M
# [02/18 23:29:07 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/18 23:29:07 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/18 23:29:07 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/18 23:29:07 d2.data.common]: Serialized dataset takes 0.10 MiB
# [02/18 23:29:07 d2.evaluation.coco_evaluation]: Trying to convert 'dentex_val' to COCO format ...
# [02/18 23:29:07 d2.data.datasets.coco]: Converting annotations of dataset 'dentex_val' to COCO format ...)
# [02/18 23:29:07 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [02/18 23:29:07 d2.data.datasets.coco]: Conversion finished, #images: 50, #annotations: 1408
# [02/18 23:29:07 d2.data.datasets.coco]: Caching COCO format annotations at '/app/data/dentex/dentex_detection/model/eval/dentex_val_coco_format.json' ...
# [02/18 23:29:07 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/18 23:29:08 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0006 s/iter. Inference: 0.0652 s/iter. Eval: 0.0003 s/iter. Total: 0.0661 s/iter. ETA=0:00:02
# [02/18 23:29:11 d2.evaluation.evaluator]: Total inference time: 0:00:03.171665 (0.070481 s / iter per device, on 1 devices)
# [02/18 23:29:11 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:03 (0.068859 s / iter per device, on 1 devices)
# [02/18 23:29:11 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/18 23:29:11 d2.evaluation.coco_evaluation]: Saving results to /app/data/dentex/dentex_detection/model/eval/coco_instances_results.json
# [02/18 23:29:11 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/18 23:29:11 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/18 23:29:11 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.04 seconds.
# [02/18 23:29:11 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/18 23:29:11 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.174
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.034
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.242
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.244
# [02/18 23:29:11 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |  AP   |  AP50  |  AP75  |  APs  |  APm  |  APl  |
# |:-----:|:------:|:------:|:-----:|:-----:|:-----:|
# | 4.327 | 17.364 | 0.562  |  nan  | 0.275 | 5.274 |
# [02/18 23:29:11 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/18 23:29:11 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/18 23:29:11 d2.evaluation.testing]: copypaste: Task: bbox
# [02/18 23:29:11 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/18 23:29:11 d2.evaluation.testing]: copypaste: 4.3267,17.3642,0.5623,nan,0.2750,5.2741
# [02/18 23:29:15 d2.utils.events]:  eta: 0:49:11  iter: 99  total_loss: 1.658  loss_cls: 0.5488  loss_box_reg: 0.8502  loss_rpn_cls: 0.06861  loss_rpn_loc: 0.1962  validation_loss: 1.656    time: 0.6059  last_time: 0.6410  data_time: 0.0053  last_data_time: 0.0050   lr: 2.4975e-05  max_mem: 5369M
# [02/18 23:29:28 d2.utils.events]:  eta: 0:49:07  iter: 119  total_loss: 1.627  loss_cls: 0.5289  loss_box_reg: 0.8524  loss_rpn_cls: 0.05658  loss_rpn_loc: 0.1941  validation_loss: 1.656    time: 0.6074  last_time: 0.6331  data_time: 0.0052  last_data_time: 0.0050   lr: 2.997e-05  max_mem: 5369M
# [02/18 23:29:40 d2.utils.events]:  eta: 0:48:48  iter: 139  total_loss: 1.589  loss_cls: 0.5063  loss_box_reg: 0.826  loss_rpn_cls: 0.05966  loss_rpn_loc: 0.1848  validation_loss: 1.656    time: 0.6070  last_time: 0.6264  data_time: 0.0051  last_data_time: 0.0052   lr: 3.4965e-05  max_mem: 5369M
# [02/18 23:29:52 d2.utils.events]:  eta: 0:48:43  iter: 159  total_loss: 1.574  loss_cls: 0.4959  loss_box_reg: 0.8338  loss_rpn_cls: 0.04723  loss_rpn_loc: 0.1757  validation_loss: 1.656    time: 0.6077  last_time: 0.5849  data_time: 0.0051  last_data_time: 0.0047   lr: 3.996e-05  max_mem: 5369M
# [02/18 23:30:04 d2.utils.events]:  eta: 0:48:40  iter: 179  total_loss: 1.506  loss_cls: 0.4789  loss_box_reg: 0.8156  loss_rpn_cls: 0.04666  loss_rpn_loc: 0.1744  validation_loss: 1.656    time: 0.6076  last_time: 0.6336  data_time: 0.0050  last_data_time: 0.0054   lr: 4.4955e-05  max_mem: 5369M
# [02/18 23:30:16 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/18 23:30:16 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/18 23:30:16 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/18 23:30:16 d2.data.common]: Serialized dataset takes 0.10 MiB
# [02/18 23:30:16 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/18 23:30:18 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0015 s/iter. Inference: 0.0672 s/iter. Eval: 0.0003 s/iter. Total: 0.0691 s/iter. ETA=0:00:02
# [02/18 23:30:20 d2.evaluation.evaluator]: Total inference time: 0:00:03.170040 (0.070445 s / iter per device, on 1 devices)
# [02/18 23:30:20 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:03 (0.068608 s / iter per device, on 1 devices)
# [02/18 23:30:20 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/18 23:30:20 d2.evaluation.coco_evaluation]: Saving results to /app/data/dentex/dentex_detection/model/eval/coco_instances_results.json
# [02/18 23:30:20 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/18 23:30:20 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/18 23:30:20 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.04 seconds.
# [02/18 23:30:20 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/18 23:30:20 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.181
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.542
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.064
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.196
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.115
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.386
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.307
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.388
# [02/18 23:30:20 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm  |  APl   |
# |:------:|:------:|:------:|:-----:|:-----:|:------:|
# | 18.141 | 54.235 | 6.129  |  nan  | 6.384 | 19.599 |
# [02/18 23:30:20 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/18 23:30:20 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/18 23:30:20 d2.evaluation.testing]: copypaste: Task: bbox
# [02/18 23:30:20 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/18 23:30:20 d2.evaluation.testing]: copypaste: 18.1411,54.2349,6.1289,nan,6.3837,19.5987
# [02/18 23:30:25 d2.utils.events]:  eta: 0:48:41  iter: 199  total_loss: 1.52  loss_cls: 0.4676  loss_box_reg: 0.8348  loss_rpn_cls: 0.04785  loss_rpn_loc: 0.1744  validation_loss: 1.544    time: 0.6087  last_time: 0.6157  data_time: 0.0051  last_data_time: 0.0045   lr: 4.995e-05  max_mem: 5369M
# [02/18 23:30:37 d2.utils.events]:  eta: 0:48:33  iter: 219  total_loss: 1.472  loss_cls: 0.4482  loss_box_reg: 0.8193  loss_rpn_cls: 0.04175  loss_rpn_loc: 0.162  validation_loss: 1.544    time: 0.6092  last_time: 0.6330  data_time: 0.0050  last_data_time: 0.0047   lr: 5.4945e-05  max_mem: 5369M
# [02/18 23:30:49 d2.utils.events]:  eta: 0:48:24  iter: 239  total_loss: 1.457  loss_cls: 0.4296  loss_box_reg: 0.8229  loss_rpn_cls: 0.04069  loss_rpn_loc: 0.1612  validation_loss: 1.544    time: 0.6094  last_time: 0.6121  data_time: 0.0052  last_data_time: 0.0052   lr: 5.994e-05  max_mem: 5369M
# [02/18 23:31:01 d2.utils.events]:  eta: 0:48:14  iter: 259  total_loss: 1.415  loss_cls: 0.4166  loss_box_reg: 0.8022  loss_rpn_cls: 0.03335  loss_rpn_loc: 0.1559  validation_loss: 1.544    time: 0.6094  last_time: 0.6233  data_time: 0.0050  last_data_time: 0.0044   lr: 6.4935e-05  max_mem: 5369M
# [02/18 23:31:14 d2.utils.events]:  eta: 0:48:03  iter: 279  total_loss: 1.387  loss_cls: 0.4025  loss_box_reg: 0.8017  loss_rpn_cls: 0.0318  loss_rpn_loc: 0.1457  validation_loss: 1.544    time: 0.6102  last_time: 0.6344  data_time: 0.0050  last_data_time: 0.0050   lr: 6.993e-05  max_mem: 5369M
# [02/18 23:31:26 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/18 23:31:26 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/18 23:31:26 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/18 23:31:26 d2.data.common]: Serialized dataset takes 0.10 MiB
# [02/18 23:31:26 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/18 23:31:27 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0007 s/iter. Inference: 0.0654 s/iter. Eval: 0.0003 s/iter. Total: 0.0664 s/iter. ETA=0:00:02
# [02/18 23:31:30 d2.evaluation.evaluator]: Total inference time: 0:00:03.109916 (0.069109 s / iter per device, on 1 devices)
# [02/18 23:31:30 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:03 (0.067333 s / iter per device, on 1 devices)
# [02/18 23:31:30 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/18 23:31:30 d2.evaluation.coco_evaluation]: Saving results to /app/data/dentex/dentex_detection/model/eval/coco_instances_results.json
# [02/18 23:31:30 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/18 23:31:30 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/18 23:31:30 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.04 seconds.
# [02/18 23:31:30 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/18 23:31:30 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.312
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.782
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.317
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.462
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.425
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.463
# [02/18 23:31:30 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 31.169 | 78.221 | 14.987 |  nan  | 21.603 | 31.697 |
# [02/18 23:31:30 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/18 23:31:30 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/18 23:31:30 d2.evaluation.testing]: copypaste: Task: bbox
# [02/18 23:31:30 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/18 23:31:30 d2.evaluation.testing]: copypaste: 31.1691,78.2212,14.9871,nan,21.6032,31.6974
# [02/18 23:31:34 d2.utils.events]:  eta: 0:47:51  iter: 299  total_loss: 1.369  loss_cls: 0.386  loss_box_reg: 0.7811  loss_rpn_cls: 0.02953  loss_rpn_loc: 0.152  validation_loss: 1.384    time: 0.6103  last_time: 0.6338  data_time: 0.0051  last_data_time: 0.0047   lr: 7.4925e-05  max_mem: 5369M
# [02/18 23:31:46 d2.utils.events]:  eta: 0:47:39  iter: 319  total_loss: 1.303  loss_cls: 0.3708  loss_box_reg: 0.7573  loss_rpn_cls: 0.02612  loss_rpn_loc: 0.1497  validation_loss: 1.384    time: 0.6102  last_time: 0.6172  data_time: 0.0053  last_data_time: 0.0051   lr: 7.992e-05  max_mem: 5369M
# [02/18 23:31:59 d2.utils.events]:  eta: 0:47:29  iter: 339  total_loss: 1.276  loss_cls: 0.3486  loss_box_reg: 0.7478  loss_rpn_cls: 0.02905  loss_rpn_loc: 0.1541  validation_loss: 1.384    time: 0.6108  last_time: 0.5904  data_time: 0.0049  last_data_time: 0.0048   lr: 8.4915e-05  max_mem: 5369M
# [02/18 23:32:12 d2.utils.events]:  eta: 0:47:21  iter: 359  total_loss: 1.213  loss_cls: 0.3417  loss_box_reg: 0.7154  loss_rpn_cls: 0.02155  loss_rpn_loc: 0.1431  validation_loss: 1.384    time: 0.6121  last_time: 0.6258  data_time: 0.0050  last_data_time: 0.0050   lr: 8.991e-05  max_mem: 5369M
# [02/18 23:32:24 d2.utils.events]:  eta: 0:47:09  iter: 379  total_loss: 1.217  loss_cls: 0.3226  loss_box_reg: 0.7178  loss_rpn_cls: 0.02177  loss_rpn_loc: 0.1485  validation_loss: 1.384    time: 0.6119  last_time: 0.6492  data_time: 0.0051  last_data_time: 0.0054   lr: 9.4905e-05  max_mem: 5369M
# [02/18 23:32:36 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/18 23:32:36 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/18 23:32:36 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/18 23:32:36 d2.data.common]: Serialized dataset takes 0.10 MiB
# [02/18 23:32:36 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/18 23:32:37 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0014 s/iter. Inference: 0.0668 s/iter. Eval: 0.0003 s/iter. Total: 0.0685 s/iter. ETA=0:00:02
# [02/18 23:32:40 d2.evaluation.evaluator]: Total inference time: 0:00:03.153914 (0.070087 s / iter per device, on 1 devices)
# [02/18 23:32:40 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:03 (0.068217 s / iter per device, on 1 devices)
# [02/18 23:32:40 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/18 23:32:40 d2.evaluation.coco_evaluation]: Saving results to /app/data/dentex/dentex_detection/model/eval/coco_instances_results.json
# [02/18 23:32:40 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/18 23:32:40 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/18 23:32:40 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.04 seconds.
# [02/18 23:32:40 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/18 23:32:40 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.394
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.874
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.247
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.242
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.398
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.187
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.513
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.396
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.515
# [02/18 23:32:40 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 39.401 | 87.382 | 24.659 |  nan  | 24.223 | 39.753 |
# [02/18 23:32:40 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/18 23:32:40 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/18 23:32:40 d2.evaluation.testing]: copypaste: Task: bbox
# [02/18 23:32:40 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/18 23:32:40 d2.evaluation.testing]: copypaste: 39.4012,87.3820,24.6593,nan,24.2233,39.7532
# [02/18 23:32:45 d2.utils.events]:  eta: 0:46:57  iter: 399  total_loss: 1.15  loss_cls: 0.3191  loss_box_reg: 0.6679  loss_rpn_cls: 0.02039  loss_rpn_loc: 0.1532  validation_loss: 1.204    time: 0.6125  last_time: 0.6428  data_time: 0.0051  last_data_time: 0.0049   lr: 9.99e-05  max_mem: 5369M
# [02/18 23:32:57 d2.utils.events]:  eta: 0:46:46  iter: 419  total_loss: 1.104  loss_cls: 0.2996  loss_box_reg: 0.6258  loss_rpn_cls: 0.01776  loss_rpn_loc: 0.145  validation_loss: 1.204    time: 0.6131  last_time: 0.6166  data_time: 0.0051  last_data_time: 0.0053   lr: 0.0001049  max_mem: 5369M
# [02/18 23:33:09 d2.utils.events]:  eta: 0:46:34  iter: 439  total_loss: 1.074  loss_cls: 0.2949  loss_box_reg: 0.5938  loss_rpn_cls: 0.01738  loss_rpn_loc: 0.1415  validation_loss: 1.204    time: 0.6127  last_time: 0.6436  data_time: 0.0051  last_data_time: 0.0069   lr: 0.00010989  max_mem: 5369M
# [02/18 23:33:22 d2.utils.events]:  eta: 0:46:22  iter: 459  total_loss: 1.006  loss_cls: 0.2583  loss_box_reg: 0.5632  loss_rpn_cls: 0.01543  loss_rpn_loc: 0.1389  validation_loss: 1.204    time: 0.6132  last_time: 0.5902  data_time: 0.0050  last_data_time: 0.0049   lr: 0.00011489  max_mem: 5369M
# [02/18 23:33:34 d2.utils.events]:  eta: 0:46:11  iter: 479  total_loss: 1.01  loss_cls: 0.2791  loss_box_reg: 0.5802  loss_rpn_cls: 0.01337  loss_rpn_loc: 0.149  validation_loss: 1.204    time: 0.6137  last_time: 0.6322  data_time: 0.0050  last_data_time: 0.0051   lr: 0.00011988  max_mem: 5369M
# [02/18 23:33:47 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/18 23:33:47 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/18 23:33:47 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/18 23:33:47 d2.data.common]: Serialized dataset takes 0.10 MiB
# [02/18 23:33:47 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/18 23:33:48 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0014 s/iter. Inference: 0.0664 s/iter. Eval: 0.0003 s/iter. Total: 0.0681 s/iter. ETA=0:00:02
# [02/18 23:33:51 d2.evaluation.evaluator]: Total inference time: 0:00:03.132999 (0.069622 s / iter per device, on 1 devices)
# [02/18 23:33:51 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:03 (0.067716 s / iter per device, on 1 devices)
# [02/18 23:33:51 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/18 23:33:51 d2.evaluation.coco_evaluation]: Saving results to /app/data/dentex/dentex_detection/model/eval/coco_instances_results.json
# [02/18 23:33:51 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/18 23:33:51 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/18 23:33:51 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.03 seconds.
# [02/18 23:33:51 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/18 23:33:51 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.430
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.905
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.333
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.235
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.435
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.197
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.538
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.307
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.543
# [02/18 23:33:51 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 43.045 | 90.533 | 33.265 |  nan  | 23.532 | 43.453 |
# [02/18 23:33:51 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/18 23:33:51 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/18 23:33:51 d2.evaluation.testing]: copypaste: Task: bbox
# [02/18 23:33:51 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/18 23:33:51 d2.evaluation.testing]: copypaste: 43.0449,90.5330,33.2654,nan,23.5323,43.4528
# [02/18 23:33:55 d2.utils.events]:  eta: 0:46:04  iter: 499  total_loss: 0.9805  loss_cls: 0.2731  loss_box_reg: 0.5474  loss_rpn_cls: 0.01348  loss_rpn_loc: 0.1375  validation_loss: 1.084    time: 0.6143  last_time: 0.6179  data_time: 0.0052  last_data_time: 0.0051   lr: 0.00012488  max_mem: 5369M
# [02/18 23:34:08 d2.utils.events]:  eta: 0:45:53  iter: 519  total_loss: 0.925  loss_cls: 0.2521  loss_box_reg: 0.5148  loss_rpn_cls: 0.01369  loss_rpn_loc: 0.1347  validation_loss: 1.084    time: 0.6148  last_time: 0.6271  data_time: 0.0052  last_data_time: 0.0049   lr: 0.00012987  max_mem: 5369M
# [02/18 23:34:20 d2.utils.events]:  eta: 0:45:40  iter: 539  total_loss: 0.9178  loss_cls: 0.2698  loss_box_reg: 0.513  loss_rpn_cls: 0.009953  loss_rpn_loc: 0.1321  validation_loss: 1.084    time: 0.6149  last_time: 0.5952  data_time: 0.0051  last_data_time: 0.0052   lr: 0.00013487  max_mem: 5369M
# [02/18 23:34:33 d2.utils.events]:  eta: 0:45:31  iter: 559  total_loss: 0.9033  loss_cls: 0.258  loss_box_reg: 0.5011  loss_rpn_cls: 0.01038  loss_rpn_loc: 0.134  validation_loss: 1.084    time: 0.6155  last_time: 0.6361  data_time: 0.0059  last_data_time: 0.0054   lr: 0.00013986  max_mem: 5369M
# [02/18 23:34:46 d2.utils.events]:  eta: 0:45:21  iter: 579  total_loss: 0.8996  loss_cls: 0.252  loss_box_reg: 0.5028  loss_rpn_cls: 0.01342  loss_rpn_loc: 0.1282  validation_loss: 1.084    time: 0.6163  last_time: 0.6232  data_time: 0.0052  last_data_time: 0.0067   lr: 0.00014486  max_mem: 5369M
# [02/18 23:34:58 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/18 23:34:58 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/18 23:34:58 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/18 23:34:58 d2.data.common]: Serialized dataset takes 0.10 MiB
# [02/18 23:34:58 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/18 23:34:59 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0012 s/iter. Inference: 0.0655 s/iter. Eval: 0.0003 s/iter. Total: 0.0671 s/iter. ETA=0:00:02
# [02/18 23:35:02 d2.evaluation.evaluator]: Total inference time: 0:00:03.113721 (0.069194 s / iter per device, on 1 devices)
# [02/18 23:35:02 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:03 (0.067365 s / iter per device, on 1 devices)
# [02/18 23:35:02 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/18 23:35:02 d2.evaluation.coco_evaluation]: Saving results to /app/data/dentex/dentex_detection/model/eval/coco_instances_results.json
# [02/18 23:35:02 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/18 23:35:02 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/18 23:35:02 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.03 seconds.
# [02/18 23:35:02 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/18 23:35:02 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.455
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.910
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.360
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.297
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.458
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.208
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.552
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.336
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.556
# [02/18 23:35:02 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 45.489 | 91.039 | 35.973 |  nan  | 29.697 | 45.834 |
# [02/18 23:35:02 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/18 23:35:02 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/18 23:35:02 d2.evaluation.testing]: copypaste: Task: bbox
# [02/18 23:35:02 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/18 23:35:02 d2.evaluation.testing]: copypaste: 45.4892,91.0388,35.9725,nan,29.6971,45.8339
# [02/18 23:35:06 d2.utils.events]:  eta: 0:45:09  iter: 599  total_loss: 0.9042  loss_cls: 0.263  loss_box_reg: 0.5013  loss_rpn_cls: 0.009232  loss_rpn_loc: 0.1294  validation_loss: 1.029    time: 0.6163  last_time: 0.5957  data_time: 0.0052  last_data_time: 0.0049   lr: 0.00014985  max_mem: 5369M
# [02/18 23:35:19 d2.utils.events]:  eta: 0:44:57  iter: 619  total_loss: 0.8941  loss_cls: 0.2431  loss_box_reg: 0.5001  loss_rpn_cls: 0.008601  loss_rpn_loc: 0.1324  validation_loss: 1.029    time: 0.6164  last_time: 0.6370  data_time: 0.0051  last_data_time: 0.0053   lr: 0.00015485  max_mem: 5369M
# [02/18 23:35:31 d2.utils.events]:  eta: 0:44:44  iter: 639  total_loss: 0.902  loss_cls: 0.2501  loss_box_reg: 0.5197  loss_rpn_cls: 0.01013  loss_rpn_loc: 0.1365  validation_loss: 1.029    time: 0.6162  last_time: 0.6165  data_time: 0.0052  last_data_time: 0.0055   lr: 0.00015984  max_mem: 5369M
# [02/18 23:35:43 d2.utils.events]:  eta: 0:44:32  iter: 659  total_loss: 0.8957  loss_cls: 0.26  loss_box_reg: 0.4931  loss_rpn_cls: 0.008466  loss_rpn_loc: 0.1328  validation_loss: 1.029    time: 0.6160  last_time: 0.6372  data_time: 0.0051  last_data_time: 0.0053   lr: 0.00016484  max_mem: 5369M
# [02/18 23:35:55 d2.utils.events]:  eta: 0:44:20  iter: 679  total_loss: 0.8662  loss_cls: 0.2403  loss_box_reg: 0.4782  loss_rpn_cls: 0.009277  loss_rpn_loc: 0.1344  validation_loss: 1.029    time: 0.6160  last_time: 0.6190  data_time: 0.0052  last_data_time: 0.0056   lr: 0.00016983  max_mem: 5369M
# [02/18 23:36:08 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/18 23:36:08 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/18 23:36:08 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/18 23:36:08 d2.data.common]: Serialized dataset takes 0.10 MiB
# [02/18 23:36:08 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/18 23:36:09 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0007 s/iter. Inference: 0.0683 s/iter. Eval: 0.0003 s/iter. Total: 0.0692 s/iter. ETA=0:00:02
# [02/18 23:36:12 d2.evaluation.evaluator]: Total inference time: 0:00:03.255375 (0.072342 s / iter per device, on 1 devices)
# [02/18 23:36:12 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:03 (0.070532 s / iter per device, on 1 devices)
# [02/18 23:36:12 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/18 23:36:12 d2.evaluation.coco_evaluation]: Saving results to /app/data/dentex/dentex_detection/model/eval/coco_instances_results.json
# [02/18 23:36:12 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/18 23:36:12 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/18 23:36:12 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.03 seconds.
# [02/18 23:36:12 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/18 23:36:12 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.469
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.409
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.312
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.472
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.215
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.346
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.573
# [02/18 23:36:12 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 46.869 | 92.332 | 40.869 |  nan  | 31.153 | 47.216 |
# [02/18 23:36:12 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/18 23:36:12 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/18 23:36:12 d2.evaluation.testing]: copypaste: Task: bbox
# [02/18 23:36:12 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/18 23:36:12 d2.evaluation.testing]: copypaste: 46.8688,92.3318,40.8687,nan,31.1528,47.2162
# [02/18 23:36:16 d2.utils.events]:  eta: 0:44:08  iter: 699  total_loss: 0.8851  loss_cls: 0.2382  loss_box_reg: 0.487  loss_rpn_cls: 0.01007  loss_rpn_loc: 0.1321  validation_loss: 1.009    time: 0.6161  last_time: 0.6573  data_time: 0.0051  last_data_time: 0.0052   lr: 0.00017483  max_mem: 5369M
# [02/18 23:36:29 d2.utils.events]:  eta: 0:43:56  iter: 719  total_loss: 0.8699  loss_cls: 0.2358  loss_box_reg: 0.4727  loss_rpn_cls: 0.007428  loss_rpn_loc: 0.1337  validation_loss: 1.009    time: 0.6162  last_time: 0.6209  data_time: 0.0052  last_data_time: 0.0052   lr: 0.00017982  max_mem: 5369M
# [02/18 23:36:41 d2.utils.events]:  eta: 0:43:43  iter: 739  total_loss: 0.8791  loss_cls: 0.2492  loss_box_reg: 0.4984  loss_rpn_cls: 0.008206  loss_rpn_loc: 0.128  validation_loss: 1.009    time: 0.6161  last_time: 0.6201  data_time: 0.0052  last_data_time: 0.0054   lr: 0.00018482  max_mem: 5369M
# [02/18 23:36:53 d2.utils.events]:  eta: 0:43:32  iter: 759  total_loss: 0.8728  loss_cls: 0.2399  loss_box_reg: 0.4838  loss_rpn_cls: 0.007214  loss_rpn_loc: 0.1341  validation_loss: 1.009    time: 0.6164  last_time: 0.6392  data_time: 0.0051  last_data_time: 0.0051   lr: 0.00018981  max_mem: 5369M
# [02/18 23:37:06 d2.utils.events]:  eta: 0:43:20  iter: 779  total_loss: 0.8448  loss_cls: 0.2407  loss_box_reg: 0.4669  loss_rpn_cls: 0.006767  loss_rpn_loc: 0.1252  validation_loss: 1.009    time: 0.6165  last_time: 0.6092  data_time: 0.0052  last_data_time: 0.0053   lr: 0.00019481  max_mem: 5369M
# [02/18 23:37:18 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/18 23:37:18 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/18 23:37:18 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/18 23:37:18 d2.data.common]: Serialized dataset takes 0.10 MiB
# [02/18 23:37:18 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/18 23:37:19 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0018 s/iter. Inference: 0.0670 s/iter. Eval: 0.0003 s/iter. Total: 0.0691 s/iter. ETA=0:00:02
# [02/18 23:37:22 d2.evaluation.evaluator]: Total inference time: 0:00:03.127308 (0.069496 s / iter per device, on 1 devices)
# [02/18 23:37:22 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:03 (0.067597 s / iter per device, on 1 devices)
# [02/18 23:37:22 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/18 23:37:22 d2.evaluation.coco_evaluation]: Saving results to /app/data/dentex/dentex_detection/model/eval/coco_instances_results.json
# [02/18 23:37:22 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/18 23:37:22 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/18 23:37:22 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [02/18 23:37:22 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/18 23:37:22 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.455
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.925
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.394
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.269
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.562
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.282
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.568
# [02/18 23:37:22 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 45.460 | 92.521 | 39.412 |  nan  | 26.934 | 45.858 |
# [02/18 23:37:22 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/18 23:37:22 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/18 23:37:22 d2.evaluation.testing]: copypaste: Task: bbox
# [02/18 23:37:22 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/18 23:37:22 d2.evaluation.testing]: copypaste: 45.4604,92.5209,39.4122,nan,26.9337,45.8577
# [02/18 23:37:26 d2.utils.events]:  eta: 0:43:08  iter: 799  total_loss: 0.8386  loss_cls: 0.2326  loss_box_reg: 0.481  loss_rpn_cls: 0.008268  loss_rpn_loc: 0.1288  validation_loss: 1.016    time: 0.6166  last_time: 0.6393  data_time: 0.0051  last_data_time: 0.0056   lr: 0.0001998  max_mem: 5369M
# [02/18 23:37:39 d2.utils.events]:  eta: 0:42:56  iter: 819  total_loss: 0.7982  loss_cls: 0.2263  loss_box_reg: 0.4564  loss_rpn_cls: 0.007395  loss_rpn_loc: 0.1233  validation_loss: 1.016    time: 0.6166  last_time: 0.6181  data_time: 0.0050  last_data_time: 0.0047   lr: 0.0002048  max_mem: 5369M
# [02/18 23:37:51 d2.utils.events]:  eta: 0:42:44  iter: 839  total_loss: 0.8665  loss_cls: 0.2428  loss_box_reg: 0.4963  loss_rpn_cls: 0.007252  loss_rpn_loc: 0.1253  validation_loss: 1.016    time: 0.6166  last_time: 0.5999  data_time: 0.0050  last_data_time: 0.0047   lr: 0.00020979  max_mem: 5369M
# [02/18 23:38:04 d2.utils.events]:  eta: 0:42:32  iter: 859  total_loss: 0.8448  loss_cls: 0.2468  loss_box_reg: 0.4919  loss_rpn_cls: 0.006155  loss_rpn_loc: 0.1279  validation_loss: 1.016    time: 0.6167  last_time: 0.5983  data_time: 0.0052  last_data_time: 0.0048   lr: 0.00021479  max_mem: 5369M
# [02/18 23:38:16 d2.utils.events]:  eta: 0:42:20  iter: 879  total_loss: 0.8559  loss_cls: 0.2394  loss_box_reg: 0.4771  loss_rpn_cls: 0.006259  loss_rpn_loc: 0.1319  validation_loss: 1.016    time: 0.6167  last_time: 0.5930  data_time: 0.0049  last_data_time: 0.0050   lr: 0.00021978  max_mem: 5369M
# [02/18 23:38:28 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/18 23:38:28 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/18 23:38:28 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/18 23:38:28 d2.data.common]: Serialized dataset takes 0.10 MiB
# [02/18 23:38:28 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/18 23:38:29 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0007 s/iter. Inference: 0.0658 s/iter. Eval: 0.0003 s/iter. Total: 0.0668 s/iter. ETA=0:00:02
# [02/18 23:38:32 d2.evaluation.evaluator]: Total inference time: 0:00:03.125664 (0.069459 s / iter per device, on 1 devices)
# [02/18 23:38:32 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:03 (0.067547 s / iter per device, on 1 devices)
# [02/18 23:38:32 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/18 23:38:32 d2.evaluation.coco_evaluation]: Saving results to /app/data/dentex/dentex_detection/model/eval/coco_instances_results.json
# [02/18 23:38:32 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/18 23:38:32 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/18 23:38:32 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [02/18 23:38:32 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/18 23:38:32 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.480
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.928
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.422
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.333
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.484
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.215
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.577
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.581
# [02/18 23:38:32 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 47.973 | 92.848 | 42.230 |  nan  | 33.326 | 48.367 |
# [02/18 23:38:32 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/18 23:38:32 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/18 23:38:32 d2.evaluation.testing]: copypaste: Task: bbox
# [02/18 23:38:32 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/18 23:38:32 d2.evaluation.testing]: copypaste: 47.9731,92.8477,42.2304,nan,33.3258,48.3674
# [02/18 23:38:37 d2.utils.events]:  eta: 0:42:08  iter: 899  total_loss: 0.8456  loss_cls: 0.2453  loss_box_reg: 0.4742  loss_rpn_cls: 0.007336  loss_rpn_loc: 0.1195  validation_loss: 0.9886    time: 0.6167  last_time: 0.6396  data_time: 0.0055  last_data_time: 0.0053   lr: 0.00022478  max_mem: 5369M
# [02/18 23:38:49 d2.utils.events]:  eta: 0:41:55  iter: 919  total_loss: 0.8462  loss_cls: 0.2259  loss_box_reg: 0.4753  loss_rpn_cls: 0.004694  loss_rpn_loc: 0.1249  validation_loss: 0.9886    time: 0.6166  last_time: 0.6238  data_time: 0.0051  last_data_time: 0.0048   lr: 0.00022977  max_mem: 5369M
# [02/18 23:39:01 d2.utils.events]:  eta: 0:41:44  iter: 939  total_loss: 0.8144  loss_cls: 0.2291  loss_box_reg: 0.4528  loss_rpn_cls: 0.008495  loss_rpn_loc: 0.1254  validation_loss: 0.9886    time: 0.6166  last_time: 0.6170  data_time: 0.0051  last_data_time: 0.0054   lr: 0.00023477  max_mem: 5369M
# [02/18 23:39:13 d2.utils.events]:  eta: 0:41:31  iter: 959  total_loss: 0.8211  loss_cls: 0.2357  loss_box_reg: 0.4638  loss_rpn_cls: 0.00707  loss_rpn_loc: 0.1227  validation_loss: 0.9886    time: 0.6164  last_time: 0.5927  data_time: 0.0050  last_data_time: 0.0050   lr: 0.00023976  max_mem: 5369M
# [02/18 23:39:26 d2.utils.events]:  eta: 0:41:19  iter: 979  total_loss: 0.8007  loss_cls: 0.2266  loss_box_reg: 0.4487  loss_rpn_cls: 0.006534  loss_rpn_loc: 0.1264  validation_loss: 0.9886    time: 0.6164  last_time: 0.5966  data_time: 0.0052  last_data_time: 0.0051   lr: 0.00024476  max_mem: 5369M
# [02/18 23:39:38 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/18 23:39:38 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/18 23:39:38 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/18 23:39:38 d2.data.common]: Serialized dataset takes 0.10 MiB
# [02/18 23:39:38 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/18 23:39:40 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0013 s/iter. Inference: 0.0664 s/iter. Eval: 0.0003 s/iter. Total: 0.0680 s/iter. ETA=0:00:02
# [02/18 23:39:42 d2.evaluation.evaluator]: Total inference time: 0:00:03.144401 (0.069876 s / iter per device, on 1 devices)
# [02/18 23:39:42 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:03 (0.068062 s / iter per device, on 1 devices)
# [02/18 23:39:42 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/18 23:39:42 d2.evaluation.coco_evaluation]: Saving results to /app/data/dentex/dentex_detection/model/eval/coco_instances_results.json
# [02/18 23:39:42 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# ...
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.591
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.597
# [02/19 00:23:18 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 48.819 | 92.791 | 45.754 |  nan  | 24.352 | 49.366 |
# [02/19 00:23:18 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/19 00:23:18 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/19 00:23:18 d2.evaluation.testing]: copypaste: Task: bbox
# [02/19 00:23:18 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/19 00:23:18 d2.evaluation.testing]: copypaste: 48.8191,92.7913,45.7543,nan,24.3516,49.3665
# [02/19 00:23:22 d2.utils.events]:  eta: 0:03:05  iter: 4699  total_loss: 0.7025  loss_cls: 0.2132  loss_box_reg: 0.3871  loss_rpn_cls: 0.002728  loss_rpn_loc: 0.1092  validation_loss: 0.9994    time: 0.6210  last_time: 0.6363  data_time: 0.0050  last_data_time: 0.0047   lr: 0.00025  max_mem: 5369M
# [02/19 00:23:34 d2.utils.events]:  eta: 0:02:53  iter: 4719  total_loss: 0.7013  loss_cls: 0.2121  loss_box_reg: 0.3878  loss_rpn_cls: 0.002834  loss_rpn_loc: 0.1111  validation_loss: 0.9994    time: 0.6210  last_time: 0.5967  data_time: 0.0050  last_data_time: 0.0051   lr: 0.00025  max_mem: 5369M
# [02/19 00:23:47 d2.utils.events]:  eta: 0:02:40  iter: 4739  total_loss: 0.727  loss_cls: 0.2193  loss_box_reg: 0.3895  loss_rpn_cls: 0.002569  loss_rpn_loc: 0.1171  validation_loss: 0.9994    time: 0.6209  last_time: 0.6187  data_time: 0.0049  last_data_time: 0.0049   lr: 0.00025  max_mem: 5369M
# [02/19 00:23:59 d2.utils.events]:  eta: 0:02:28  iter: 4759  total_loss: 0.6717  loss_cls: 0.2093  loss_box_reg: 0.3669  loss_rpn_cls: 0.002664  loss_rpn_loc: 0.1054  validation_loss: 0.9994    time: 0.6209  last_time: 0.6404  data_time: 0.0051  last_data_time: 0.0049   lr: 0.00025  max_mem: 5369M
# [02/19 00:24:11 d2.utils.events]:  eta: 0:02:16  iter: 4779  total_loss: 0.7195  loss_cls: 0.2218  loss_box_reg: 0.3848  loss_rpn_cls: 0.00327  loss_rpn_loc: 0.1105  validation_loss: 0.9994    time: 0.6209  last_time: 0.6380  data_time: 0.0050  last_data_time: 0.0046   lr: 0.00025  max_mem: 5369M
# [02/19 00:24:24 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/19 00:24:24 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 00:24:24 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/19 00:24:24 d2.data.common]: Serialized dataset takes 0.10 MiB
# [02/19 00:24:24 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/19 00:24:25 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0009 s/iter. Inference: 0.0657 s/iter. Eval: 0.0002 s/iter. Total: 0.0668 s/iter. ETA=0:00:02
# [02/19 00:24:27 d2.evaluation.evaluator]: Total inference time: 0:00:03.150660 (0.070015 s / iter per device, on 1 devices)
# [02/19 00:24:27 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:03 (0.068202 s / iter per device, on 1 devices)
# [02/19 00:24:27 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/19 00:24:27 d2.evaluation.coco_evaluation]: Saving results to /app/data/dentex/dentex_detection/model/eval/coco_instances_results.json
# [02/19 00:24:27 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/19 00:24:27 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/19 00:24:27 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [02/19 00:24:27 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/19 00:24:27 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.499
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.931
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.463
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.281
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.503
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.597
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.603
# [02/19 00:24:27 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 49.856 | 93.061 | 46.318 |  nan  | 28.062 | 50.324 |
# [02/19 00:24:27 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/19 00:24:27 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/19 00:24:27 d2.evaluation.testing]: copypaste: Task: bbox
# [02/19 00:24:27 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/19 00:24:27 d2.evaluation.testing]: copypaste: 49.8556,93.0608,46.3176,nan,28.0619,50.3242
# [02/19 00:24:32 d2.utils.events]:  eta: 0:02:03  iter: 4799  total_loss: 0.6548  loss_cls: 0.1934  loss_box_reg: 0.3629  loss_rpn_cls: 0.002376  loss_rpn_loc: 0.102  validation_loss: 0.9852    time: 0.6209  last_time: 0.6179  data_time: 0.0049  last_data_time: 0.0049   lr: 0.00025  max_mem: 5369M
# [02/19 00:24:44 d2.utils.events]:  eta: 0:01:51  iter: 4819  total_loss: 0.6809  loss_cls: 0.2065  loss_box_reg: 0.3741  loss_rpn_cls: 0.003445  loss_rpn_loc: 0.1074  validation_loss: 0.9852    time: 0.6208  last_time: 0.6190  data_time: 0.0052  last_data_time: 0.0056   lr: 0.00025  max_mem: 5369M
# [02/19 00:24:56 d2.utils.events]:  eta: 0:01:38  iter: 4839  total_loss: 0.6929  loss_cls: 0.2065  loss_box_reg: 0.3782  loss_rpn_cls: 0.003401  loss_rpn_loc: 0.1079  validation_loss: 0.9852    time: 0.6208  last_time: 0.6355  data_time: 0.0053  last_data_time: 0.0051   lr: 0.00025  max_mem: 5369M
# [02/19 00:25:09 d2.utils.events]:  eta: 0:01:26  iter: 4859  total_loss: 0.6407  loss_cls: 0.184  loss_box_reg: 0.3374  loss_rpn_cls: 0.001709  loss_rpn_loc: 0.09947  validation_loss: 0.9852    time: 0.6208  last_time: 0.6197  data_time: 0.0053  last_data_time: 0.0053   lr: 0.00025  max_mem: 5369M
# [02/19 00:25:21 d2.utils.events]:  eta: 0:01:14  iter: 4879  total_loss: 0.6696  loss_cls: 0.2023  loss_box_reg: 0.3549  loss_rpn_cls: 0.00261  loss_rpn_loc: 0.1096  validation_loss: 0.9852    time: 0.6207  last_time: 0.5966  data_time: 0.0053  last_data_time: 0.0052   lr: 0.00025  max_mem: 5369M
# [02/19 00:25:33 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/19 00:25:33 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 00:25:33 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/19 00:25:33 d2.data.common]: Serialized dataset takes 0.10 MiB
# [02/19 00:25:33 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/19 00:25:34 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0009 s/iter. Inference: 0.0655 s/iter. Eval: 0.0002 s/iter. Total: 0.0666 s/iter. ETA=0:00:02
# [02/19 00:25:37 d2.evaluation.evaluator]: Total inference time: 0:00:03.103593 (0.068969 s / iter per device, on 1 devices)
# [02/19 00:25:37 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:03 (0.067145 s / iter per device, on 1 devices)
# [02/19 00:25:37 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/19 00:25:37 d2.evaluation.coco_evaluation]: Saving results to /app/data/dentex/dentex_detection/model/eval/coco_instances_results.json
# [02/19 00:25:37 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/19 00:25:37 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/19 00:25:37 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [02/19 00:25:37 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/19 00:25:37 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.496
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.939
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.266
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.501
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.595
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.311
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.601
# [02/19 00:25:37 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 49.554 | 93.871 | 46.825 |  nan  | 26.569 | 50.061 |
# [02/19 00:25:37 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/19 00:25:37 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/19 00:25:37 d2.evaluation.testing]: copypaste: Task: bbox
# [02/19 00:25:37 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/19 00:25:37 d2.evaluation.testing]: copypaste: 49.5542,93.8713,46.8254,nan,26.5694,50.0611
# [02/19 00:25:41 d2.utils.events]:  eta: 0:01:01  iter: 4899  total_loss: 0.7126  loss_cls: 0.2082  loss_box_reg: 0.3682  loss_rpn_cls: 0.001689  loss_rpn_loc: 0.1142  validation_loss: 0.9432    time: 0.6207  last_time: 0.5905  data_time: 0.0053  last_data_time: 0.0050   lr: 0.00025  max_mem: 5369M
# [02/19 00:25:53 d2.utils.events]:  eta: 0:00:49  iter: 4919  total_loss: 0.6929  loss_cls: 0.2123  loss_box_reg: 0.3761  loss_rpn_cls: 0.002733  loss_rpn_loc: 0.1047  validation_loss: 0.9432    time: 0.6206  last_time: 0.5916  data_time: 0.0053  last_data_time: 0.0053   lr: 0.00025  max_mem: 5369M
# [02/19 00:26:06 d2.utils.events]:  eta: 0:00:37  iter: 4939  total_loss: 0.6775  loss_cls: 0.2012  loss_box_reg: 0.3621  loss_rpn_cls: 0.003257  loss_rpn_loc: 0.1072  validation_loss: 0.9432    time: 0.6206  last_time: 0.6195  data_time: 0.0052  last_data_time: 0.0056   lr: 0.00025  max_mem: 5369M
# [02/19 00:26:18 d2.utils.events]:  eta: 0:00:24  iter: 4959  total_loss: 0.6882  loss_cls: 0.2082  loss_box_reg: 0.357  loss_rpn_cls: 0.001951  loss_rpn_loc: 0.1046  validation_loss: 0.9432    time: 0.6206  last_time: 0.6417  data_time: 0.0051  last_data_time: 0.0052   lr: 0.00025  max_mem: 5369M
# [02/19 00:26:30 d2.utils.events]:  eta: 0:00:12  iter: 4979  total_loss: 0.6943  loss_cls: 0.2146  loss_box_reg: 0.3778  loss_rpn_cls: 0.001777  loss_rpn_loc: 0.1066  validation_loss: 0.9432    time: 0.6206  last_time: 0.6383  data_time: 0.0051  last_data_time: 0.0051   lr: 0.00025  max_mem: 5369M
# [02/19 00:26:48 d2.utils.events]:  eta: 0:00:00  iter: 4999  total_loss: 0.6821  loss_cls: 0.2038  loss_box_reg: 0.3735  loss_rpn_cls: 0.002113  loss_rpn_loc: 0.11  validation_loss: 1.012    time: 0.6205  last_time: 0.5990  data_time: 0.0051  last_data_time: 0.0048   lr: 0.00025  max_mem: 5369M
# [02/19 00:26:48 d2.engine.hooks]: Overall training speed: 4998 iterations in 0:51:41 (0.6205 s / it)
# [02/19 00:26:48 d2.engine.hooks]: Total training time: 0:58:41 (0:07:00 on hooks)
# [02/19 00:26:48 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/19 00:26:48 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 00:26:48 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/19 00:26:48 d2.data.common]: Serialized dataset takes 0.10 MiB
# [02/19 00:26:48 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/19 00:26:49 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0013 s/iter. Inference: 0.0655 s/iter. Eval: 0.0002 s/iter. Total: 0.0670 s/iter. ETA=0:00:02
# [02/19 00:26:52 d2.evaluation.evaluator]: Total inference time: 0:00:03.100333 (0.068896 s / iter per device, on 1 devices)
# [02/19 00:26:52 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:03 (0.067081 s / iter per device, on 1 devices)
# [02/19 00:26:52 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/19 00:26:52 d2.evaluation.coco_evaluation]: Saving results to /app/data/dentex/dentex_detection/model/eval/coco_instances_results.json
# [02/19 00:26:52 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/19 00:26:52 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/19 00:26:52 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [02/19 00:26:52 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/19 00:26:52 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.500
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.932
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.470
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.322
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.503
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.223
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.396
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.597
# [02/19 00:26:52 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 50.012 | 93.227 | 46.957 |  nan  | 32.188 | 50.309 |
# [02/19 00:26:52 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/19 00:26:52 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/19 00:26:52 d2.evaluation.testing]: copypaste: Task: bbox
# [02/19 00:26:52 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/19 00:26:52 d2.evaluation.testing]: copypaste: 50.0125,93.2267,46.9575,nan,32.1883,50.3089
